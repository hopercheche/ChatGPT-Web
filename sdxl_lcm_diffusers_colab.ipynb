# %% [markdown]
# <a href="https://colab.research.google.com/github/hopercheche/ChatGPT-Web/blob/main/sdxl_lcm_diffusers_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q diffusers transformers accelerate peft

from diffusers import UNet2DConditionModel, DiffusionPipeline, LCMScheduler
import torch

unet = UNet2DConditionModel.from_pretrained("latent-consistency/lcm-sdxl", torch_dtype=torch.float16, variant="fp16")
pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0", unet=unet, torch_dtype=torch.float16, variant="fp16")

pipe.scheduler = LCMScheduler.from_config(pipe.scheduler.config)
pipe.to("cuda")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 28.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 34.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.7/174.7 kB 23.7 MB/s eta 0:00:00
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# config.json:   0%|          | 0.00/1.83k [00:00<?, ?B/s]
# diffusion_pytorch_model.fp16.safetensors:   0%|          | 0.00/5.14G [00:00<?, ?B/s]
# model_index.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/565 [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/479 [00:00<?, ?B/s]
# ...

# %%
prompt = "a close-up picture of a fluffy cat"
image = pipe(prompt, num_inference_steps=4, guidance_scale=8.0).images[0]
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
from diffusers import UNet2DConditionModel, DiffusionPipeline, LCMScheduler
import torch

unet = UNet2DConditionModel.from_pretrained("latent-consistency/lcm-sdxl", torch_dtype=torch.float16, variant="fp16")
pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0", unet=unet, torch_dtype=torch.float16, variant="fp16")

pipe.scheduler = LCMScheduler.from_config(pipe.scheduler.config)
pipe.to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# The config attributes {'skip_prk_steps': True} were passed to LCMScheduler, but are not expected and will be ignored. Please verify your scheduler_config.json configuration file.
# StableDiffusionXLPipeline {
#   "_class_name": "StableDiffusionXLPipeline",
#   "_diffusers_version": "0.23.1",
#   "_name_or_path": "stabilityai/stable-diffusion-xl-base-1.0",
#   "force_zeros_for_empty_prompt": true,
#   "scheduler": [
#     "diffusers",
#     "LCMScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "text_encoder_2": [
#     "transformers",
#     "CLIPTextModelWithProjection"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "tokenizer_2": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
prompt="portrait photo of a girl, photograph, highly detailed face, depth of field, moody light, golden hour, style by Dan Winters, Russell James, Steve McCurry, centered, extremely detailed, Nikon D850, award winning photography"

# %%
# %time images = pipe(prompt, num_inference_steps=4,num_images_per_prompt=2, guidance_scale=8.0).images
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# CPU times: user 8.92 s, sys: 771 ms, total: 9.69 s
# Wall time: 10 s

# %%
images[1]
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %%
# !wget https://civitai.com/api/download/models/192916 --content-disposition /content
# Out:
# --2023-11-18 13:57:16--  https://civitai.com/api/download/models/192916
# Resolving civitai.com (civitai.com)... 104.18.23.206, 104.18.22.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.23.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod-2023-11-01.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1307119/E5A2A8E5B9BDE4BABAE980A0.SgGa.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22MoyouArtificial_v1060.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20231118/us-east-1/s3/aws4_request&X-Amz-Date=20231118T135716Z&X-Amz-SignedHeaders=host&X-Amz-Signature=0f4287192bab43b8ccfb7d08bb1d14de1238f85e899eee8f779d3f8b14713607 [following]
# ...

# %%
# !git clone https://github.com/huggingface/diffusers
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 48522, done.
# remote: Counting objects: 100% (495/495), done.
# remote: Compressing objects: 100% (257/257), done.
# remote: Total 48522 (delta 298), reused 355 (delta 213), pack-reused 48027
# Receiving objects: 100% (48522/48522), 30.49 MiB | 22.72 MiB/s, done.
# Resolving deltas: 100% (35807/35807), done.

# %%
# !pip install omegaconf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=85505cff44a2bf8069fcbebff6d6d1755b42949ea5caa5bd203e23ff338a59ed
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built antlr4-python3-runtime
# ...

# %%
# %cd ./diffusers

# assume you have downloaded xxx.safetensors, it will out save_dir in diffusers format.
# !python ./scripts/convert_original_stable_diffusion_to_diffusers.py --checkpoint_path /content/MoyouArtificial_v1060.safetensors  --dump_path /content/MoyouArtificial_v1060 --from_safetensors
# Out:
# /content/diffusers
# 2023-11-18 14:05:13.593898: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-18 14:05:13.593953: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-18 14:05:13.593991: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-18 14:05:15.790638: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# config.json: 100% 4.52k/4.52k [00:00<00:00, 16.3MB/s]
# tokenizer_config.json: 100% 905/905 [00:00<00:00, 4.19MB/s]
# vocab.json: 100% 961k/961k [00:00<00:00, 7.29MB/s]
# ...

# %%
import torch
from diffusers import StableDiffusionPipeline, DDIMScheduler, LMSDiscreteScheduler

scheduler = DDIMScheduler(beta_start=0.00085, beta_end=0.012, beta_schedule="scaled_linear", clip_sample=False, set_alpha_to_one=False)

lms = LMSDiscreteScheduler(
    beta_start=0.00085,
    beta_end=0.012,
    beta_schedule="scaled_linear"
)


pipeline = StableDiffusionPipeline.from_pretrained(
    "/content/MoyouArtificial_v1060", scheduler=lms,torch_dtype=torch.float16
).to("cuda")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/diffusers/pipelines/stable_diffusion/pipeline_stable_diffusion.py:132: FutureWarning: The configuration file of this scheduler: LMSDiscreteScheduler {
#   "_class_name": "LMSDiscreteScheduler",
#   "_diffusers_version": "0.23.1",
#   "beta_end": 0.012,
#   "beta_schedule": "scaled_linear",
#   "beta_start": 0.00085,
#   "num_train_timesteps": 1000,
#   "prediction_type": "epsilon",
#   "steps_offset": 0,
#   "timestep_spacing": "linspace",
#   "trained_betas": null,
#   "use_karras_sigmas": false
# }
#  is outdated. `steps_offset` should be set to 1 instead of 0. Please make sure to update the config accordingly as leaving `steps_offset` might led to incorrect results in future versions. If you have downloaded this checkpoint from the Hugging Face Hub, it would be very nice if you could open a Pull request for the `scheduler/scheduler_config.json` file
# ...

# %%
prompt = "1boy,handsome,mature male,face,half-length portrait,white background,ultra short hair,"
negative_prompt="(worst quality:2),(low quality:2),(normal quality:2),lowres,watermark,"
images = pipeline(prompt,negative_prompt=negative_prompt, guidance_scale=7.5, height=512, width=512,num_images_per_prompt=4,num_inference_steps=50).images
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
images[2].save("test.png")

# %%
# !pip install diffusers==0.18.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.23.1
#     Uninstalling diffusers-0.23.1:
#       Successfully uninstalled diffusers-0.23.1
# ...

# %%
# !pip install xformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 MB 6.6 MB/s eta 0:00:00
# ...

# %%
import torch
from PIL import Image
from diffusers import ControlNetModel, DiffusionPipeline
from diffusers.utils import load_image
from safetensors.torch import load_file
from diffusers import StableDiffusionPipeline
from diffusers import DPMSolverMultistepScheduler
source_image = load_image('/content/test.png')

def resize_for_condition_image(input_image: Image, resolution: int):
    input_image = input_image.convert("RGB")
    W, H = input_image.size
    k = float(resolution) / min(H, W)
    H *= k
    W *= k
    H = int(round(H / 64.0)) * 64
    W = int(round(W / 64.0)) * 64
    img = input_image.resize((W, H), resample=Image.LANCZOS)
    return img

controlnet = ControlNetModel.from_pretrained('lllyasviel/control_v11f1e_sd15_tile',
                                            torch_dtype=torch.float16)
pipe = DiffusionPipeline.from_pretrained("/content/MoyouArtificial_v1060",
                                         custom_pipeline="stable_diffusion_controlnet_img2img",
                                         controlnet=controlnet,
                                         torch_dtype=torch.float16).to('cuda')
#pipe.enable_xformers_memory_efficient_attention()

#source_image = load_image('https://huggingface.co/lllyasviel/control_v11f1e_sd15_tile/resolve/main/images/original.png')

condition_image = resize_for_condition_image(source_image, 1024)
image = pipe(prompt="full-face view,best quality",
             negative_prompt="blur, lowres, bad anatomy, bad hands, cropped, worst quality",
             image=condition_image,
             controlnet_conditioning_image=condition_image,
             width=condition_image.size[0],
             height=condition_image.size[1],
             strength=1.0,
             #generator=torch.manual_seed(0),
             num_inference_steps=32,
            ).images[0]
# Out:
# The config attributes {'attention_type': 'default', 'dropout': 0.0, 'reverse_transformer_layers_per_block': None} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# The config attributes {'force_upcast': True} were passed to AutoencoderKL, but are not expected and will be ignored. Please verify your config.json configuration file.
#   0%|          | 0/32 [00:00<?, ?it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>
